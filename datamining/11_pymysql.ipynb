# %%
import pymysql

host = 'localhost'
port = 3307
user = 'root'
passwd = '1234567890'
db = 'TESTDB'
charset = 'utf8mb4'

conn = pymysql.connect(host=host, port=port, user=user, passwd=passwd, db=db, charset=charset)
print('Successfully connected!')

cursor = conn.cursor()
# Out:
# Successfully connected!

# %%
sql = """
INSERT INTO Staff (ID, Name, DeptId, Age, Gender, Salary, recordDt)
VALUES ('001', 'Mike', '002', 45, 'M', 60000, '2020-04-24 14:59:57');
"""

# 將指令放進 cursor 物件，並執行
cursor.execute(sql)
# Out:
# 1

# %%
conn.commit()

# %%
sql = "select * from Staff"
cursor.execute(sql)
# Out:
# 1

# %%
cursor.fetchall()
# Out:
# (('001',
#   'Mike',
#   '002',
#   45,
#   'M',
#   60000,
#   datetime.datetime(2020, 4, 24, 14, 59, 57)),)

# %%
cursor.fetchall()
# Out:
# ()

# %%
sql = "delete from Staff"
cursor.execute(sql)
conn.commit()

# %%
sql_insert = """
INSERT INTO Staff (ID, Name, DeptId, Age, Gender, Salary, recordDt)
VALUES (%s, %s, %s, %s, %s, %s, %s);
"""

values = [('001', 'Mike', '002', '45', 'M', '60000', '2020-10-13 21:41:49'),
 ('002', 'Judy', '002', '30', 'F', '48000', '2020-10-13 21:41:49'),
 ('003', 'Allen', '001', '22', 'M', '50000', '2020-10-13 21:41:49'),
 ('004', 'Tom', '002', '47', 'M', '47000', '2020-10-13 21:41:49'),
 ('005', 'Jack', '003', '36', 'M', '52000', '2020-10-13 21:41:49'),
 ('006', 'Abby', '002', '24', 'F', '45000', '2020-10-13 21:41:49'),
 ('007', 'Trump', '001', '80', 'M', '80000', '2020-10-13 21:41:49'),
 ('008', 'Marry', '003', '29', 'F', '87000', '2020-10-13 21:41:49')]

# %%
conn.rollback()

# %%
print('新增資料筆數:', cursor.executemany(sql_insert, values))
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print('新增資料筆數:', cursor.executemany(sql_insert, values))
#
# File ~/side-project/tibame/cki101/datamining/.venv/lib/python3.14/site-packages/pymysql/cursors.py:188, in Cursor.executemany(self, query, args)
#     186     q_postfix = m.group(3) or ""
#     187     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 188     return self._do_execute_many(
#     189         q_prefix,
#     190         q_values,
#     191         q_postfix,
#     192         args,
#     193         self.max_stmt_length,
#     194         self._get_db().encoding,
#     195     )
#     197 self.rowcount = sum(self.execute(query, arg) for arg in args)
#     198 return self.rowcount
#
# File ~/side-project/tibame/cki101/datamining/.venv/lib/python3.14/site-packages/pymysql/cursors.py:226, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     224         sql += b","
#     225     sql += v
# --> 226 rows += self.execute(sql + postfix)
#     227 self.rowcount = rows
#     228 return rows
#
# File ~/side-project/tibame/cki101/datamining/.venv/lib/python3.14/site-packages/pymysql/cursors.py:159, in Cursor.execute(self, query, args)
#     155     pass
#     157 query = self.mogrify(query, args)
# --> 159 result = self._query(query)
#     160 self._executed = query
#     161 return result
#
# File ~/side-project/tibame/cki101/datamining/.venv/lib/python3.14/site-packages/pymysql/cursors.py:330, in Cursor._query(self, q)
#     328 conn = self._get_db()
#     329 self._clear_result()
# --> 330 conn.query(q)
#     331 self._do_get_result()
#     332 return self.rowcount
#
# File ~/side-project/tibame/cki101/datamining/.venv/lib/python3.14/site-packages/pymysql/connections.py:582, in Connection.query(self, sql, unbuffered)
#     580     sql = sql.encode(self.encoding, "surrogateescape")
#     581 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 582 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     583 return self._affected_rows
#
# File ~/side-project/tibame/cki101/datamining/.venv/lib/python3.14/site-packages/pymysql/connections.py:847, in Connection._read_query_result(self, unbuffered)
#     845     result.init_unbuffered_query()
#     846 else:
# --> 847     result.read()
#     848 self._result = result
#     849 if result.server_status is not None:
#
# File ~/side-project/tibame/cki101/datamining/.venv/lib/python3.14/site-packages/pymysql/connections.py:1245, in MySQLResult.read(self)
#    1243 def read(self):
#    1244     try:
# -> 1245         first_packet = self.connection._read_packet()
#    1247         if first_packet.is_ok_packet():
#    1248             self._read_ok_packet(first_packet)
#
# File ~/side-project/tibame/cki101/datamining/.venv/lib/python3.14/site-packages/pymysql/connections.py:803, in Connection._read_packet(self, packet_type)
#     801     if self._result is not None and self._result.unbuffered_active is True:
#     802         self._result.unbuffered_active = False
# --> 803     packet.raise_for_error()
#     804 return packet
#
# File ~/side-project/tibame/cki101/datamining/.venv/lib/python3.14/site-packages/pymysql/protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~/side-project/tibame/cki101/datamining/.venv/lib/python3.14/site-packages/pymysql/err.py:154, in raise_mysql_exception(data)
#     152 if errorclass is None:
#     153     errorclass = InternalError if errno < 1000 else OperationalError
# --> 154 raise errorclass(errno, errval, sqlstate=sqlstate)
#
# IntegrityError: (1062, "Duplicate entry '001' for key 'Staff.PRIMARY'")

# %%
conn.commit()

# %%
cursor.execute("select * from Staff")
# Out:
# 8

# %%
cursor.close()
conn.close()
