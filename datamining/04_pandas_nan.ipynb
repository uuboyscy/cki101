# %%
import pandas as pd

df = pd.read_csv("employees.csv")
df
# Out:
#   employee_id         name   department   salary                    email
# 0        E001   Alice Chen  Engineering  95000.0   alice.chen@company.com
# 1        E002    Bob Smith    Marketing  72000.0                      NaN
# 2        E003  Carol White          NaN  68000.0  carol.white@company.com
# 3        E004          NaN          NaN  55000.0                      NaN
# 4        E005  Eve Johnson        Sales      NaN  eve.johnson@company.com
# 5        E006          NaN          NaN      NaN                      NaN

# %%
type(None)
# Out:
# NoneType

# %%
None

# %%
df["salary"][4]
# Out:
# np.float64(nan)

# %%
df["salary"].mean()
# Out:
# np.float64(72500.0)

# %%
df["salary"].fillna(0)
# Out:
# 0    95000.0
# 1    72000.0
# 2    68000.0
# 3    55000.0
# 4        0.0
# 5        0.0
# Name: salary, dtype: float64

# %%
df["salary"].fillna(0).mean()
# Out:
# np.float64(48333.333333333336)

# %%
df["salary"] = df["salary"].fillna(0)
df
# Out:
#   employee_id         name   department   salary                    email
# 0        E001   Alice Chen  Engineering  95000.0   alice.chen@company.com
# 1        E002    Bob Smith    Marketing  72000.0                      NaN
# 2        E003  Carol White          NaN  68000.0  carol.white@company.com
# 3        E004          NaN          NaN  55000.0                      NaN
# 4        E005  Eve Johnson        Sales      0.0  eve.johnson@company.com
# 5        E006          NaN          NaN      0.0                      NaN

# %%
df.dropna()
# Out:
#   employee_id         name   department   salary                    email
# 0        E001   Alice Chen  Engineering  95000.0   alice.chen@company.com
# 4        E005  Eve Johnson        Sales      0.0  eve.johnson@company.com

# %%
df.dropna(thresh=2)
# Out:
#   employee_id         name   department   salary                    email
# 0        E001   Alice Chen  Engineering  95000.0   alice.chen@company.com
# 1        E002    Bob Smith    Marketing  72000.0                      NaN
# 2        E003  Carol White          NaN  68000.0  carol.white@company.com
# 3        E004          NaN          NaN  55000.0                      NaN
# 4        E005  Eve Johnson        Sales      0.0  eve.johnson@company.com
# 5        E006          NaN          NaN      0.0                      NaN

# %%
df.dropna(thresh=3)
# Out:
#   employee_id         name   department   salary                    email
# 0        E001   Alice Chen  Engineering  95000.0   alice.chen@company.com
# 1        E002    Bob Smith    Marketing  72000.0                      NaN
# 2        E003  Carol White          NaN  68000.0  carol.white@company.com
# 4        E005  Eve Johnson        Sales      0.0  eve.johnson@company.com

# %%
df["name"].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# Name: name, dtype: bool

# %%
df[df["name"].isnull()]
# Out:
#   employee_id name department   salary email
# 3        E004  NaN        NaN  55000.0   NaN
# 5        E006  NaN        NaN      0.0   NaN

# %%
df[df["name"].isna()]
# Out:
#   employee_id name department   salary email
# 3        E004  NaN        NaN  55000.0   NaN
# 5        E006  NaN        NaN      0.0   NaN

# %%
df[df["name"].notna()]
# Out:
#   employee_id         name   department   salary                    email
# 0        E001   Alice Chen  Engineering  95000.0   alice.chen@company.com
# 1        E002    Bob Smith    Marketing  72000.0                      NaN
# 2        E003  Carol White          NaN  68000.0  carol.white@company.com
# 4        E005  Eve Johnson        Sales      0.0  eve.johnson@company.com

# %%
df
# Out:
#   employee_id         name   department   salary                    email
# 0        E001   Alice Chen  Engineering  95000.0   alice.chen@company.com
# 1        E002    Bob Smith    Marketing  72000.0                      NaN
# 2        E003  Carol White          NaN  68000.0  carol.white@company.com
# 3        E004          NaN          NaN  55000.0                      NaN
# 4        E005  Eve Johnson        Sales      0.0  eve.johnson@company.com
# 5        E006          NaN          NaN      0.0                      NaN

# %%
df["department"].ffill()
# Out:
# 0    Engineering
# 1      Marketing
# 2      Marketing
# 3      Marketing
# 4          Sales
# 5          Sales
# Name: department, dtype: str

# %%
df["department"] = df["department"].ffill()
df
# Out:
#   employee_id         name   department   salary                    email
# 0        E001   Alice Chen  Engineering  95000.0   alice.chen@company.com
# 1        E002    Bob Smith    Marketing  72000.0                      NaN
# 2        E003  Carol White    Marketing  68000.0  carol.white@company.com
# 3        E004          NaN    Marketing  55000.0                      NaN
# 4        E005  Eve Johnson        Sales      0.0  eve.johnson@company.com
# 5        E006          NaN        Sales      0.0                      NaN

# %%
import numpy as np

# %%
np.where(
    df["email"].isna(),
    "unknown",
    df["email"],
)
# Out:
# array(['alice.chen@company.com', 'unknown', 'carol.white@company.com',
#        'unknown', 'eve.johnson@company.com', 'unknown'], dtype=object)

# %%
df["email"] = np.where(
    df["email"].isna(),
    "unknown",
    df["email"],
)

df
# Out:
#   employee_id         name   department   salary                    email
# 0        E001   Alice Chen  Engineering  95000.0   alice.chen@company.com
# 1        E002    Bob Smith    Marketing  72000.0                  unknown
# 2        E003  Carol White    Marketing  68000.0  carol.white@company.com
# 3        E004          NaN    Marketing  55000.0                  unknown
# 4        E005  Eve Johnson        Sales      0.0  eve.johnson@company.com
# 5        E006          NaN        Sales      0.0                  unknown

# %%
for i in range(5):
    print(i, "odd" if i%2 == 1 else "even")
# Out:
# 0 even
# 1 odd
# 2 even
# 3 odd
# 4 even
