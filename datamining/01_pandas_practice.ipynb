# %%
import pandas as pd

# %%
columns = ["Name", "Age", "Height"]
df = pd.DataFrame(columns=columns)
df
# Out:
# Empty DataFrame
# Columns: [Name, Age, Height]
# Index: []

# %%
df.loc[0] = ["Allen", 22, 175]
df
# Out:
#     Name  Age  Height
# 0  Allen   22     175

# %%
df.loc[1] = ["Ted", 25, 180]
df
# Out:
#     Name  Age  Height
# 0  Allen   22     175
# 1    Ted   25     180

# %%
data = [
    ["Allen", 22, 175],
    ["Ted", 25, 180],
]

df = pd.DataFrame(
    data=data,
    columns=columns,
)

df
# Out:
#     Name  Age  Height
# 0  Allen   22     175
# 1    Ted   25     180

# %%
df["Weight"] = [75, 80]
df
# Out:
#     Name  Age  Height  Weight
# 0  Allen   22     175      75
# 1    Ted   25     180      80

# %%
df.drop("Weight", axis=1)
# Out:
#     Name  Age  Height
# 0  Allen   22     175
# 1    Ted   25     180

# %%
df
# Out:
#     Name  Age  Height  Weight
# 0  Allen   22     175      75
# 1    Ted   25     180      80

# %%
df = df.drop("Weight", axis=1)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df = df.drop("Weight", axis=1)
#       2 df
#
# File ~/side-project/tibame/cki101/datamining/.venv/lib/python3.14/site-packages/pandas/core/frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6296                 weight  250.0   150.0
#    6297         falcon  speed   320.0   250.0
#    6298                 weight  1.0     0.8
#    6299         """
# -> 6300         return super().drop(
#    6301             labels=labels,
#    6302             axis=axis,
#    6303             index=index,
#
# File ~/side-project/tibame/cki101/datamining/.venv/lib/python3.14/site-packages/pandas/core/generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
# ...

# %%
df.drop(1)
# Out:
#     Name  Age  Height
# 0  Allen   22     175

# %%
df["Height"]
# Out:
# 0    175
# 1    180
# Name: Height, dtype: int64

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   22     175
# 1    Ted   25     180

# %%
df["Height"][1]
# Out:
# np.int64(180)

# %%
df["Height"][1] = 188
# Out:
# /var/folders/_k/k5dry95j0q5d35_9pn5d86vm0000gn/T/ipykernel_24765/352499047.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   df["Height"][1] = 188

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   22     175
# 1    Ted   25     180

# %%
df.loc[1, "Height"] = 188

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   22     175
# 1    Ted   25     188

# %%
df.loc[1, ["Height", "Age"]]
# Out:
# Height    188
# Age        25
# Name: 1, dtype: int64

# %%
df.loc[[0, 1], ["Height", "Age"]]
# Out:
#    Height  Age
# 0     175   22
# 1     188   25

# %%
df.loc[0:, "Height":]
# Out:
#    Height
# 0     175
# 1     188

# %%
df["Height"]
# Out:
# 0    175
# 1    188
# Name: Height, dtype: int64

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   22     175
# 1    Ted   25     188

# %%
df2 = df

# %%
df2["Height"] = 100
df2
# Out:
#     Name  Age  Height
# 0  Allen   22     100
# 1    Ted   25     100

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   22     100
# 1    Ted   25     100

# %%
df3 = df.copy()

# %%
df3["Age"] = 55
df3
# Out:
#     Name  Age  Height
# 0  Allen   55     100
# 1    Ted   55     100

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   22     100
# 1    Ted   25     100

# %%
# async
# await
