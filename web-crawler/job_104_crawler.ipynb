szLDBW3Grrbp091ffC8k7bkMBdUH.WG9r_hgdYnNGIbGy83zAofOssTK5NXTnb1GIZWBtRbxp4iFA; __cf_bm=Ul7vPevoap54zQLVcbtQBXG49iiCK8AmSZN9.sLDu3Y-1780111527.1178832-1.0.1.1-uJsvykPEUTNS_mFWqFj_8rX348GtwQsjKxxYnf2AXOF6JU2LXCdsMSC88H2OPm0IitM8_pkmkZSUTIvzGMK6NioRXAsqW3fNV8nPYAcXlaxmm0vsXrEHghBnL.ea2yMW; _hjSession_3218023=eyJpZCI6IjAyMTM0Nzg2LTJlYzEtNGU0Yy05OWNkLTQzZmU4MWM5MjdlMCIsImMiOjE3ODAxMTE1Mjc0NzksInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=; SMART_BANNER=0; lup=315306588.4507568175053.4623532291991.1.4640712161167; lunp=4623532291991; _ga_FJWMQR9J2K=GS2.1.s1780111526$o10$g1$t1780112239$j57$l0$h0; _ga_W9X1GB1SVR=GS2.1.s1780111526$o10$g1$t1780112239$j57$l0$h0; _ga_WYQPBGBV8Z=GS2.4.s1780111526$o9$g1$t1780112243$j52$l0$h0"""
cookies = {kv.strip().split("=")[0]: kv.strip().split("=")[1] for kv in cookies_str.split(";")}
cookies
# Out:
# {'_hjSessionUser_3218023': 'eyJpZCI6ImU3Y2UxNjQwLTE2ZjgtNTVmYi05MDIzLTE1OWQzMjA4YmQwMCIsImNyZWF0ZWQiOjE3MzIzNjcyNzk2MjEsImV4aXN0aW5nIjp0cnVlfQ',
#  'ACUD': 'de282a24-56ac-4930-94bc-8e6dc7f2eab9',
#  '_hjSessionUser_642678': 'eyJpZCI6ImU0ZGNiNjhiLWZlMDItNTAyZi1iNTQxLWY2NjE3MmE4ZTViZiIsImNyZWF0ZWQiOjE3NTM2ODEyNzk0ODgsImV4aXN0aW5nIjp0cnVlfQ',
#  '_hjMinimizedPolls': '1539041%2C1639209%2C829535',
#  '_ga': 'GA1.1.1122682954.1777621324',
#  '_fbp': 'fb.2.1777621323947.812643339867016028',
#  'luauid': '315306588',
#  'dtCookie': 'v_4_srv_4_sn_A9870F1343D1AC31DCE3561C8D57DD58_perc_100000_ol_0_mul_1_app-3Aea7c4b59f27d43eb_0',
#  '_hp2_id.3192618648': '%7B%22userId%22%3A%226167284254382822%22%2C%22pageviewId%22%3A%223863274384616240%22%2C%22sessionId%22%3A%226446489039604737%22%2C%22identity%22%3Anull%2C%22trackerVersion%22%3A%224.0%22%7D',
#  '_ga_TTXLT7SQ8E': 'GS2.1.s1777722756$o1$g0$t1777722762$j54$l0$h0',
#  'EPK': '8c79039e-1486-4edf-9773-5d7e025a846e',
#  'LLM': 'google',
# ...

# %%
cookie_string = """_hjSessionUser_3218023=eyJpZCI6ImU3Y2UxNjQwLTE2ZjgtNTVmYi05MDIzLTE1OWQzMjA4YmQwMCIsImNyZWF0ZWQiOjE3MzIzNjcyNzk2MjEsImV4aXN0aW5nIjp0cnVlfQ==; ACUD=de282a24-56ac-4930-94bc-8e6dc7f2eab9; _hjSessionUser_642678=eyJpZCI6ImU0ZGNiNjhiLWZlMDItNTAyZi1iNTQxLWY2NjE3MmE4ZTViZiIsImNyZWF0ZWQiOjE3NTM2ODEyNzk0ODgsImV4aXN0aW5n
MiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=; SMART_BANNER=0; lup=315306588.4507568175053.4623532291991.1.4640712161167; lunp=4623532291991; _ga_FJWMQR9J2K=GS2.1.s1780111526$o10$g1$t1780112239$j57$l0$h0; _ga_W9X1GB1SVR=GS2.1.s1780111526$o10$g1$t1780112239$j57$l0$h0; _ga_WYQPBGBV8Z=GS2.4.s1780111526$o9$g1$t1780112243$j52$l0$h0"""

# Split by '; ' to get individual key-value pairs
# Then split each pair by '=' only once to create the dict
cookies_dict = {
    item.split('=', 1)[0].strip(): item.split('=', 1)[1] 
    for item in cookie_string.split(';') 
    if '=' in item
}

# Print a few to verify
print(f"Total cookies found: {len(cookies_dict)}")
print(f"LLM Value: {cookies_dict.get('LLM')}")
cookies_dict
# Out:
# Total cookies found: 36
# LLM Value: google
# {'_hjSessionUser_3218023': 'eyJpZCI6ImU3Y2UxNjQwLTE2ZjgtNTVmYi05MDIzLTE1OWQzMjA4YmQwMCIsImNyZWF0ZWQiOjE3MzIzNjcyNzk2MjEsImV4aXN0aW5nIjp0cnVlfQ==',
#  'ACUD': 'de282a24-56ac-4930-94bc-8e6dc7f2eab9',
#  '_hjSessionUser_642678': 'eyJpZCI6ImU0ZGNiNjhiLWZlMDItNTAyZi1iNTQxLWY2NjE3MmE4ZTViZiIsImNyZWF0ZWQiOjE3NTM2ODEyNzk0ODgsImV4aXN0aW5nIjp0cnVlfQ==',
#  '_hjMinimizedPolls': '1539041%2C1639209%2C829535',
#  '_ga': 'GA1.1.1122682954.1777621324',
#  '_fbp': 'fb.2.1777621323947.812643339867016028',
#  'luauid': '315306588',
#  'dtCookie': 'v_4_srv_4_sn_A9870F1343D1AC31DCE3561C8D57DD58_perc_100000_ol_0_mul_1_app-3Aea7c4b59f27d43eb_0',
#  '_hp2_id.3192618648': '%7B%22userId%22%3A%226167284254382822%22%2C%22pageviewId%22%3A%223863274384616240%22%2C%22sessionId%22%3A%226446489039604737%22%2C%22identity%22%3Anull%2C%22trackerVersion%22%3A%224.0%22%7D',
#  '_ga_TTXLT7SQ8E': 'GS2.1.s1777722756$o1$g0$t1777722762$j54$l0$h0',
# ...

# %%
res = requests.get(url, headers=headers, cookies=cookies)
res
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# {'data': [{'appearDate': '20260527',
#    'applyCnt': 10,
#    'coIndustry': 1011001002,
#    'coIndustryDesc': '建築工程業',
#    'custName': '忠泰建設股份有限公司',
#    'custNo': '22957034000',
#    'description': '1.\t集團數據中台建設與管理：\n-\t設計並執行跨系統資料管道（ETL），將多公司數據清洗、標準化後匯入集團 CRM，優化整體資訊流。\n-\t制定集團數據標準規範，負責資料庫（SQL/NoSQL）效能優化與生命週期管理。\n-\t主導資料去識別化與資安合',
#    'descSnippet': '1.\t集團數據中台建設與管理：\n-\t設計並執行跨系統[[[資料]]]管道（ETL），將多公司數據清洗、標準化後匯入集團 CRM，優化整體資訊流。\n-\t制定集團數據標準規範，負責[[[資料]]]庫（SQL/NoSQL）效能優化與生命週期管理。\n-\t主導[[[資料]]]去識別化與資安合',
#    'mrtDist': 0.5,
#    'jobAddress': '市民大道三段178號8樓',
#    'jobAddrNo': 6001001005,
#    'jobAddrNoDesc': '台北市大安區',
#    'jobName': 'CRM數據工程師',
#    'jobNameSnippet': 'CRM[[[數據工程師]]]',
#    'jobNo': '15165937',
#    'jobRo': 1,
#    'jobType': 0,
#    'lat': 25.044253,
#    'lon': 121.5372504,
#    'link': {'job': 'https://www.104.com.tw/job/91241',
#     'cust': 'https://www.104.com.tw/company/ajo0wsw',
# ...
